# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine = pd.read_csv('C:\\Users\\aiden\\dev\\kaggle\\python\\wine_quality.csv')

# %%
wine.shape

# %%
wine.info()

# %%
wine.describe()
